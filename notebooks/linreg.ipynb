# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Load the dataframe
data = pd.read_csv(input("Please enter a dataset name or location: "))

# Extract the features (X) and the target variable (y)
X = data[input("Please enter a valid column value: ")].values.reshape(-1, 1)
y = data[input("Please enter a valid column value: ")].values

# Create and fit the linear regression model
model = LinearRegression()
model.fit(X, y)

# Predict the target variable
y_pred = model.predict(X)

# Plot the original data and the linear regression line
plt.scatter(X, y, color='blue', label='Original data')
plt.plot(X, y_pred, color='red', label='Linear regression line')
plt.xlabel(input("Please enter a label for x axis: "))
plt.ylabel(input("Please enter a label for y axis: "))
plt.legend()
plt.show()
# Out:
# Please enter a dataset name or location:  data.csv
# Please enter a valid column value:  radius_mean
# Please enter a valid column value:  area_mean
# Please enter a label for x axis:  Radius Mean
# Please enter a label for y axis:  Area Mean
